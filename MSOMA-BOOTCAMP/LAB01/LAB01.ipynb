# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
data = pd.read_csv('data.csv')
data
# Out:
#         ID    Name in English     Name in French      Name in Spanish  \
# 0     1022      South Italian     italien du sud  napolitano-calabrés
# 1     1023           Sicilian           sicilien            siciliano
# 2      383          Low Saxon          bas-saxon           bajo sajón
# 3      335         Belarusian         biélorusse           bielorruso
# 4      382            Lombard            lombard             lombardo
# ...    ...                ...                ...                  ...
# 2717  1972           Yonaguni           yonaguni             yonaguni
# 2718  2018             Yucuna             yucuna               yucuna
# 2719  2015  Yurutí (Colombia)  yurutí (Colombie)    yurutí (Colombia)
# 2720  2716          Zangskari          zangskari            zangskari
# 2721  2177            Zidgali            zidgali              zidgali
#
#                                               Countries  \
# 0                                                 Italy
# ...

# %%
import matplotlib.pyplot as plt

  

height = [607, 680, 253, 554, 628]
  
tick_label = ['Critically endangered', 'Definitely endangered','Extinct'  'Severely endangered', 'Vulnerable']
  

plt.bar(left, height, tick_label = tick_label,
        width = 0.8, color = ['red', 'green'])
  
# naming the x-axis
plt.xlabel('Degree of endangerment')
# naming the y-axis
plt.ylabel('Number of languages')
# plot title
plt.title('The number of languages by degree of endangerment')
  
# function to show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-eabe9b6b5c95> in <module>
#       9
#      10 plt.bar(left, height, tick_label = tick_label,
# ---> 11         width = 0.8, color = ['red', 'green'])
#      12
#      13 # naming the x-axis
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
# -> 2441         **({"data": data} if data is not None else {}), **kwargs)
#    2442
#    2443
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...
